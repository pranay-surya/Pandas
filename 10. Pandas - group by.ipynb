# %% [markdown]
# ## Group by in pandas
#      In Pandas, groupby() is used to split data into groups based on one or more columns,
#      perform operations on each group, and then combine the results
#
#      The groupby() function follows the Split–Apply–Combine approach:
#      - Split the DataFrame into groups based on a column
#      - Apply a function (such as sum, mean, count) to each group
#      - Combine the results into a new DataFrame or Series

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Dell\\Desktop\\_PANDAS_\\Data\\student_result1.csv")
df.head(2)
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80

# %% [markdown]
# ###             --- Basic Grouping ---
# #### Create a GroupBy object based on the 'Section' column

# %%
gr = df.groupby(by= 'Section')
gr

# %%
gr.groups
# Out:
# {'A': [0, 2], 'B': [1], 'C': [3, 4]}

# %% [markdown]
# ### --- Grouping by Multiple Columns ---
# #### Group data by both 'Student ID' and 'Section' to see specific row mappings

# %%
df.groupby(['Student ID','Section']).groups
# Out:
# {(1001, 'A'): [0], (1002, 'B'): [1], (1003, 'A'): [2], (1004, 'C'): [3], (1005, 'C'): [4]}

# %% [markdown]
# ### --- Iterating through Groups ---
# #### Loop through each group and print the data belonging to that specific Section

# %%
for Section, df_1 in gr:
    print(df_1)
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 2        1003       A     10          3                       2          60
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 1        1002       B     10          6                       2          80
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %% [markdown]
# ### --- Selecting Specific Groups ---
# #### Re-group by 'Class' and extract only the data for Class 10

# %%
gr = df.groupby("Class").get_group(10)    # Access the particular col. with given value  
gr
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60

# %% [markdown]
# #### Extract records where students achieved exactly a 50% result

# %%
gr = df.groupby("Percentage").get_group(50)
gr
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50

# %% [markdown]
# ### --- Group Aggregations ---
# #### Group by Section and calculate the sum of all numerical columns

# %%
gr_1 = df.groupby("Section")   
gr_1.sum()
# Out:
#          Student ID  Class  Study hrs  Social Media usage hrs  Percentage
# Section
# A              2004     20          5                       5         110
# B              1002     10          6                       2          80
# C              2009     23          5                       3         120

# %%
gr_1.mean()
# Out:
#          Student ID  Class  Study hrs  Social Media usage hrs  Percentage
# Section
# A            1002.0   10.0        2.5                     2.5        55.0
# B            1002.0   10.0        6.0                     2.0        80.0
# C            1004.5   11.5        2.5                     1.5        60.0

# %%
gr_1.describe()
# Out:
#         Student ID                                                      \
#              count    mean       std     min      25%     50%      75%
# Section
# A              2.0  1002.0  1.414214  1001.0  1001.50  1002.0  1002.50
# B              1.0  1002.0       NaN  1002.0  1002.00  1002.0  1002.00
# C              2.0  1004.5  0.707107  1004.0  1004.25  1004.5  1004.75
#
#                 Class        ... Social Media usage hrs      Percentage        \
#             max count  mean  ...                    75%  max      count  mean
# Section                      ...
# A        1003.0   2.0  10.0  ...                   2.75  3.0        2.0  55.0
# B        1002.0   1.0  10.0  ...                   2.00  2.0        1.0  80.0
# C        1005.0   2.0  11.5  ...                   1.75  2.0        2.0  60.0
#
#
#                std   min   25%   50%   75%   max
# Section
# A         7.071068  50.0  52.5  55.0  57.5  60.0
# B              NaN  80.0  80.0  80.0  80.0  80.0
# C        21.213203  45.0  52.5  60.0  67.5  75.0
#
# [3 rows x 40 columns]

# %% [markdown]
# ### --- Advanced Aggregation ---

# %%
df = pd.read_csv("C:\\Users\\Dell\\Desktop\\_PANDAS_\\Data\\student_result1.csv")
df.head()
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %% [markdown]
# #### Apply multiple specific aggregate functions simultaneously to each group

# %%
gr_1.agg(['sum', 'max', 'mean','std'])
# Out:
#         Student ID                         Class                      \
#                sum   max    mean       std   sum max  mean       std
# Section
# A             2004  1003  1002.0  1.414214    20  10  10.0  0.000000
# B             1002  1002  1002.0       NaN    10  10  10.0       NaN
# C             2009  1005  1004.5  0.707107    23  12  11.5  0.707107
#
#         Study hrs                    Social Media usage hrs           \
#               sum max mean       std                    sum max mean
# Section
# A               5   3  2.5  0.707107                      5   3  2.5
# B               6   6  6.0       NaN                      2   2  2.0
# C               5   5  2.5  3.535534                      3   2  1.5
#
#                   Percentage
#               std        sum max  mean        std
# Section
# A        0.707107        110  60  55.0   7.071068
# B             NaN         80  80  80.0        NaN
# C        0.707107        120  75  60.0  21.213203
